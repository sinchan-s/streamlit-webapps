# %%
import openpyxl as xl
import pandas as pd

# %%
exl = xl.load_workbook('qa-sept23.xlsx')
df = exl.active

# %%
for row in range(0, df.max_row):
    for col in df.iter_cols(1, df.max_column):
        print(col[row].value)
# Out:
# 2023-09-30 00:00:00
# Print Production
# None
# None
# None
# None
# None
# None
# None
# None
# Yarn Dyed  Production
# None
# None
# None
# None
# None
# WIP
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ...

# %%
df_new = pd.read_excel('qa-sept23.xlsx', sheet_name='Data', skiprows=[0], index_col=0)
df_new
# Out:
#                        Print   Print Yd  Print PD Yardage   Print Yd Yardage   \
# DATE
# 2023-09-01 00:00:00   13132.5       0.0             136.00                0.0
# 2023-09-02 00:00:00   16410.1    1258.0             333.00                0.0
# 2023-09-03 00:00:00   66328.0     128.0               0.00                0.0
# 2023-09-04 00:00:00   36518.7       0.0             215.00                0.0
# 2023-09-05 00:00:00   20743.0      26.0             359.10                0.0
# 2023-09-06 00:00:00   38733.7       0.0             374.00                0.0
# 2023-09-07 00:00:00   32033.0       0.0             162.00                0.0
# 2023-09-08 00:00:00   32631.3    1141.0             423.04                0.0
# 2023-09-09 00:00:00   47167.7       0.0             234.00                0.0
# 2023-09-10 00:00:00   36377.7       0.0               0.00                0.0
# 2023-09-11 00:00:00   71644.0       0.0             304.00               38.0
# ...

# %%
df_new.describe()
# Out:
#               Print       Print Yd  Print PD Yardage   Print Yd Yardage   \
# count      30.000000     30.000000          30.000000          30.000000
# mean    53646.690000   1346.766667         232.835000           2.100000
# std     29145.940903   3065.037803         143.831116           8.172072
# min     13132.500000      0.000000           0.000000           0.000000
# 25%     36064.200000      0.000000         137.005000           0.000000
# 50%     47963.400000    144.500000         237.510000           0.000000
# 75%     70315.000000   1228.750000         327.250000           0.000000
# max    153893.000000  15756.000000         492.140000          38.000000
#
#        Piece Dyed         RG/RS    PRINT Q6    Print FRC  PRINT TOTAL  \
# count    30.000000    30.000000   27.000000    30.000000          0.0
# mean    391.533333   148.233333  169.074074   752.062667          NaN
# std     915.312524   412.510370  112.761125   330.772587          NaN
# ...

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31 entries, 2023-09-01 00:00:00 to Total
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Print              30 non-null     float64
#  1   Print Yd           30 non-null     float64
#  2   Print PD Yardage   30 non-null     float64
#  3   Print Yd Yardage   30 non-null     float64
#  4   Piece Dyed         30 non-null     float64
#  5   RG/RS              30 non-null     float64
#  6   PRINT Q6           27 non-null     float64
#  7   Print FRC          30 non-null     float64
#  8   PRINT TOTAL        0 non-null      float64
#  9   Yarn Dyed          30 non-null     float64
#  10  Yarn Dyed Yardage  30 non-null     float64
#  11  RG/RS.1            30 non-null     float64
#  12  YD Q6              29 non-null     float64
#  13  Yarn Dyed FRC      30 non-null     float64
#  14  YD TOTAL           0 non-null      float64
# ...

# %%
df_new.head()
# Out:
#                       Print   Print Yd  Print PD Yardage   Print Yd Yardage   \
# DATE
# 2023-09-01 00:00:00  13132.5       0.0              136.0                0.0
# 2023-09-02 00:00:00  16410.1    1258.0              333.0                0.0
# 2023-09-03 00:00:00  66328.0     128.0                0.0                0.0
# 2023-09-04 00:00:00  36518.7       0.0              215.0                0.0
# 2023-09-05 00:00:00  20743.0      26.0              359.1                0.0
#
#                      Piece Dyed    RG/RS  PRINT Q6  Print FRC  PRINT TOTAL  \
# DATE
# 2023-09-01 00:00:00         55.0   175.0     143.0      201.0          NaN
# 2023-09-02 00:00:00          0.0     7.0     115.0      564.0          NaN
# 2023-09-03 00:00:00          0.0   327.0      30.0      739.0          NaN
# 2023-09-04 00:00:00        128.0     0.0     100.0      483.0          NaN
# 2023-09-05 00:00:00       3527.0  2146.0     124.0      433.0          NaN
#
# ...
