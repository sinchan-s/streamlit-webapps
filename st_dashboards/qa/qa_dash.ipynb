# %%
import openpyxl as xl
import pandas as pd

# %%
exl = xl.load_workbook('qa-sept23.xlsx')
df = exl.active

# %%
for row in range(0, df.max_row):
    for col in df.iter_cols(1, df.max_column):
        print(col[row].value)
# Out:
# None
#    AURO TEXTILE-II
# None
# None
# None
# None
# None
# None
# None
# None
# None
#          DAILY QA PRODUCTION REPORT
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# DATE
# =Data!A1
# None
# None
# None
# None
# None
# None
# None
# None
# PRODUCTION
# FTD
# MTD
# PRO-TARGET
# PACKING % (FTD)
# PACKING % MTD)
# LAST MONTH PKG %AGE
# None
# None
# None
# TOTAL PRODUCTION
# =Summary!I7
# =Summary!J7
# 40.00 Lac
# =AVERAGE(F7,F8)
# =AVERAGE(G7,G8)
# =AVERAGE(H7,H8)
# None
# None
# None
# YARN DYED
# =Summary!G7
# =Summary!H7
# 22.00 Lac
# =+Summary!H30%
# =+Summary!I30%
# 0.9721
# None
# None
# None
# PRINT
# =Summary!C7
# =Summary!D7
# 18.00 Lac
# =+Summary!H25%
# =+Summary!I25%
# 0.9481
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
df_new = pd.read_excel('qa-sept23.xlsx')
df_new
# Out:
#                                           Unnamed: 0  \
# 0                                                NaN
# 1                                                NaN
# 2                                1970-01-01 05:30:00
# 3                                             PRINT
# 4                                         PARAMETERS
# 5   TOTAL PRODUCTION (include plant frc & cut piece)
# 6                             TOTAL PRINT PRODUCTION
# 7                             PRINTED P/D PRODUCTION
# 8                        PRINTED YARNDYED PRODUCTION
# 9                     PRINTED P/D YARDAGE PRODUCTION
# 10                    PRINTED Y/D YARDAGE PRODUCTION
# 11                             PIECE DYED PRODUCTION
# 12       Print FRC (including plant frc & cut piece)
# 13                                  RG/RS PRODUCTION
# 14                                               NaN
# 15                                               NaN
# 16                               C-GRADE & Q6 DETAIL
# 17                                               NaN
# 18                                               NaN
# 19                                               NaN
# 20                                               NaN
# 21                                               NaN
# 22                                               NaN
# 23                                               NaN
# 24                                               NaN
# 25                                               NaN
# 26                                               NaN
# 27                                               NaN
# 28                                               NaN
#
#                         DAILY QA PRODUCTION REPORT  Unnamed: 2  Unnamed: 3  \
# 0                                    GROUPING (QA)         NaN         NaN
# 1   Grouping Quality classification summary report         NaN         NaN
# 2                                              NaN         NaN         NaN
# 3                                              NaN         NaN         NaN
# 4                                              NaN  FTD (MTRS)  MTD (MTRS)
# 5                                              NaN         NaN         NaN
# 6                                              NaN         NaN         NaN
# 7                                              NaN         NaN         NaN
# 8                                              NaN         NaN         NaN
# 9                                              NaN         NaN         NaN
# 10                                             NaN         NaN         NaN
# 11                                             NaN         NaN         NaN
# 12                                             NaN         NaN         NaN
# 13                                             NaN         NaN         NaN
# 14                                             NaN         NaN         NaN
# 15                                        CATEGORY         NaN         FTD
# 16                           (Q.A) RG/RS REJECTION         NaN         NaN
# 17                      (Q.A) BASE SHADE REJECTION         NaN         NaN
# 18                      (Q.A)PRINT SHADE REJECTION         NaN         NaN
# 19                       (Q.A) REJECTION FOR OTHER         NaN         NaN
# 20                  REJECTION FOR PRINT BY FOLDING         NaN         NaN
# 21                          PRINT Q6 (PPC SURPLUS)         NaN         NaN
# 22                             PRINT Q6 BY FOLDING         NaN         NaN
# 23                TOTAL REJECTION+FRC FOR PRINT+Q6         NaN         NaN
# 24             REJECTION FOR  YARN DYED BY FOLDING         NaN         NaN
# 25                    REJECTION FOR YARN DYED(Q.A)         NaN         NaN
# 26                      YARN DYED Q6 (PPC SURPLUS)         NaN         NaN
# 27                         YARN DYED Q6 BY FOLDING         NaN         NaN
# 28            TOTAL REJECTION+FRC FOR YARN DYED+Q6         NaN         NaN
#
#                                           Unnamed: 4 Unnamed: 5  Unnamed: 6  \
# 0                                                NaN        NaN         NaN
# 1                                                NaN        NaN         NaN
# 2                                                NaN        NaN         NaN
# 3                                         YARN-DYED         NaN         NaN
# 4                                         PARAMETERS        NaN  FTD (MTRS)
# 5   TOTAL PRODUCTION (include plant frc & cut piece)        NaN         NaN
# 6                         TOTAL YARN DYED PRODUCTION        NaN         NaN
# 7                          BULK YARN DYED PRODUCTION        NaN         NaN
# 8                       YARN DYED YARDAGE PRODUCTION        NaN         NaN
# 9                                                NaN        NaN         NaN
# 10                                               NaN        NaN         NaN
# 11                                               NaN        NaN         NaN
# 12   Yarn dyed FRC (including plant frc & cut piece)        NaN         NaN
# 13                                  RG/RS PRODUCTION        NaN         NaN
# 14                                               NaN        NaN         NaN
# 15                                               MTD    AVERAGE       % AGE
# 16                                               NaN        NaN         NaN
# 17                                               NaN        NaN         NaN
# 18                                               NaN        NaN         NaN
# 19                                               NaN        NaN         NaN
# 20                                               NaN        NaN         NaN
# 21                                               NaN        NaN         NaN
# 22                                               NaN        NaN         NaN
# 23                                               NaN        NaN         NaN
# 24                                               NaN        NaN         NaN
# 25                                               NaN        NaN         NaN
# 26                                               NaN        NaN         NaN
# 27                                               NaN        NaN         NaN
# 28                                               NaN        NaN         NaN
#
#              Unnamed: 7           Unnamed: 8  Unnamed: 9
# 0                   NaN                  NaN         NaN
# 1                   NaN                  NaN         NaN
# 2                   NaN                  NaN         NaN
# 3                   NaN     TOTAL PRODUCTION         NaN
# 4            MTD (MTRS)           FTD (MTRS)  MTD (MTRS)
# 5                   NaN                  NaN         NaN
# 6                   NaN                  NaN         NaN
# 7                   NaN                  NaN         NaN
# 8                   NaN                  NaN         NaN
# 9                   NaN                  NaN         NaN
# 10                  NaN                  NaN         NaN
# 11                  NaN                  NaN         NaN
# 12                  NaN                  NaN         NaN
# 13                  NaN                  NaN         NaN
# 14                  NaN                  NaN         NaN
# 15                  NaN                  NaN         NaN
# 16                  NaN                  NaN         NaN
# 17                  NaN                  NaN         NaN
# 18                  NaN                  NaN         NaN
# 19                  NaN                  NaN         NaN
# 20                  NaN                  NaN         NaN
# 21                  NaN                  NaN         NaN
# 22  Print Packing % FTD  Print Packing % MTD         NaN
# 23                  NaN                  NaN         NaN
# 24                  NaN                  NaN         NaN
# 25                  NaN                  NaN         NaN
# 26                  NaN                  NaN         NaN
# 27     YD Packing % FTD     YD Packing % MTD         NaN
# 28                  NaN                  NaN         NaN
